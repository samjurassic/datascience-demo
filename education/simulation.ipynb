# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %%
n = 10000

# %%
X = pd.DataFrame()
X["gender"] = np.random.binomial(1, 0.5, n)
X["age"] = np.random.normal(20, 4, n)
xb = -9 + 3.5 * X.gender + 0.2 * X.age
p = 1/(1 + np.exp(-xb))
y = np.random.binomial(1, p, n)
clf = LogisticRegression(random_state=0).fit(X, y)
clf.coef_

# %%
mean = [4, 5]
cov = [[1, 5], [5, 100]]

df_pass = pd.DataFrame(np.random.multivariate_normal(mean, cov, 200))
df_pass["y"] = "Pass"

mean = [8, 15]
cov = [[5, 6], [6, 20]]

df_fail = pd.DataFrame(np.random.multivariate_normal(mean, cov, 50))
df_fail["y"] = "Fail"

df_combined = pd.concat([df_pass, df_fail])

sns.scatterplot(df_combined, x=0, y=1, hue="y")

# %% [markdown]
# - student id
# - age
# - major
# - midterm grade
# - assignments missed
# - days of school missed
# - full-time
# - job
# - family
# - borough
# - age
# - distance to campus

# %%
# age, distance to campus, gpa
mean = [19, 4.0, 3.1]
sd = [3, 2, 0.5]
cov = np.eye(3) * sd

# pd.DataFrame(np.random.multivariate_normal(mean, cov, 50))

# %%
mean = [0, 0]
cov = [[1, -0.8], [-0.8, 1]]

df = pd.DataFrame(np.random.multivariate_normal(mean, cov, 500), columns=["A", "B"])

sns.scatterplot(df, x="A", y="B")

LinearRegression().fit(X=df["A"].to_numpy().reshape(-1, 1), y=df["B"]).coef_
# Out:
# array([-0.79538534])

# %%
a = np.array([1, 2, 3, 4, 5, 6, 7, 8])
b = np.array([2, 3, 4, 5, 5, 7, 8, 9])
np.cov(a, b)

# %%
students = 10

def simulate_student_profile(n: int) -> pd.DataFrame:

    df = pd.DataFrame()

    # borough
    boroughs = ["Bronx", "Brooklyn", "Manhattan", "Queens", "Staten Island", "Outside NYC"]
    borough_p = [0.14, 0.21, 0.12, 0.13, 0.02, 0.38]
    df["borough"] = np.random.choice(boroughs, n, p=borough_p)

    # age
    df["age"] = np.random.normal(20, 4, n).round()

    # major (degree type?)
    majors = ["Computer Science", "Information Technology"]
    major_p = [0.8, 0.2]
    df["major"] = np.random.choice(majors, n, p=major_p)

    # full-time
    df["full_time"] = np.random.binomial(1, 0.8, n)

    # first-generation college
    df["first_generation"] = np.random.binomial(1, 0.5, n)

    # employed
    df["employed"] = np.random.binomial(1, 0.3, n)

    # pell grant recipient
    df["pell_grant"] = np.random.binomial(1, 0.45, n)


    return df

simulate_student_profile(n=students)
# Out:
#        borough   age                   major  full_time  first_generation  \
# 0     Brooklyn  22.0        Computer Science          1                 0
# 1  Outside NYC  16.0        Computer Science          0                 1
# 2  Outside NYC  24.0        Computer Science          0                 0
# 3  Outside NYC  25.0  Information Technology          1                 0
# 4     Brooklyn  16.0        Computer Science          1                 1
# 5  Outside NYC  17.0        Computer Science          1                 1
# 6  Outside NYC  19.0  Information Technology          1                 0
# 7     Brooklyn  20.0        Computer Science          1                 1
# 8        Bronx  14.0        Computer Science          0                 1
# 9        Bronx  21.0        Computer Science          1                 0
#
#    employed  pell_grant
# 0         0           0
# 1         0           0
# 2         1           0
# 3         0           0
# 4         0           1
# ...
